# %% [markdown]
# <a href="https://colab.research.google.com/github/Rijann12/01-Introduction_to_Ml-pandas.ipynb/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Daty 1 ML Practice

# %% [markdown]
# ## Pandas
# - Data processing in ML using pandas
# Data Processing is required tasks for cleaning the data and maming it suitable for machine learnng model which aslso increases the accuracy and efficnecy of a ml model.
# - Pandas is an open source Python package that is most widely used for data science/ data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for mukti-dimensional arrays. Preprocessing iis the process of doing a pre-analysis of data, in order to trnasform them into a standard and normalized format.
# - Preprocessing involves the following aspects:
#  -  missing values
#  - data standarization
#  - data normalization
#  - data minning

# %%
import pandas as pd

# %%
data ={
    "cars": ["BMW", "Tesla", "BYD", "suzuki"],
    "models": ["2007", "2023", "2020", "2008"],
    "passenger": ["4", "5", "6", "8"]
}
#print(data)
data
# Out:
# {'cars': ['BMW', 'Tesla', 'BYD', 'suzuki'],
#  'models': ['2007', '2023', '2020', '2008'],
#  'passenger': ['4', '5', '6', '8']}

# %%
# convert the data into dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     BMW   2007         4
# 1   Tesla   2023         5
# 2     BYD   2020         6
# 3  suzuki   2008         8

# %%
# save the file as csv file
df.to_csv("/content/drive/MyDrive/ML practice/car_data.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# Pandas Series
import pandas as pd
a= [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# create labels in panda with index
#replace row 0,1,2,.. by a,b,c
a= [1, 7, 2]
myvar = pd.Series(a, index=["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
# how to access series
print(myvar["x"])
# Out:
# 1

# %%
#task: Create a dataframe named df with data calories and duration.
import pandas as pd
data ={
    "calories": [200, 500,420],
    "duration": [40, 30 ,45]
}
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       200        40
# 1       500        30
# 2       420        45

# %%
print(df.loc[1])
# Out:
# calories    500
# duration     30
# Name: 1, dtype: int64

# %%
print(df.loc[[0,1]])
# Out:
#    calories  duration
# 0       200        40
# 1       500        30

# %%
print(df.loc[[0,2]])
# Out:
#    calories  duration
# 0       200        40
# 2       420        45

# %%
import pandas as pd
data ={
    "calories": [200, 500,420],
    "duration": [40, 30 ,45]
}
df = pd.DataFrame(data, index=["Day1", "Day2", "Day3"])
print(df)
# Out:
#       calories  duration
# Day1       200        40
# Day2       500        30
# Day3       420        45

# %%
print(df.loc['Day2'])
# Out:
# calories    500
# duration     30
# Name: Day2, dtype: int64

# %%
#Practice
import pandas as pd

# %% [markdown]
# # Day 2 ML Practice

# %% [markdown]
# ## Data Cleaning with Pandas
# ## Bad data can be
# - empty cells
# - data in wrong format
# - wrong data
# - Duplicates

# %%
#clean pandas_dataset.csv
import pandas as pd
df= pd.read_csv(r"/content/drive/MyDrive/ML practice/pandas_dataset.csv")
df
# Out:
#     Unnamed: 0  Duration         Date  Pulse  Maxpulse  Calories
# 0            0        60  2020/12/01'    110       130    409.10
# 1            1        60  2020/12/02'    117       145    479.00
# 2            2        60  2020/12/03'    103       135    340.00
# 3            3        45  2020/12/04'    109       175    282.40
# 4            4        45  2020/12/05'    117       148    406.00
# 5            5        60  2020/12/06'    102       127    300.00
# 6            6        60  2020/12/07'    110       136    374.00
# 7            7       450  2020/12/08'    104       134    253.30
# 8            8        30  2020/12/09'    109       133    195.10
# 9            9        60  2020/12/10'     98       124    269.00
# 10          10        60  2020/12/11'    103       147    329.30
# 11          11        60  2020/12/12'    100       120    250.70
# 12          12        60  2020/12/12'    100       120    250.70
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Duration         Date  Pulse  Maxpulse  Calories
# 0           0        60  2020/12/01'    110       130     409.1
# 1           1        60  2020/12/02'    117       145     479.0
# 2           2        60  2020/12/03'    103       135     340.0
# 3           3        45  2020/12/04'    109       175     282.4
# 4           4        45  2020/12/05'    117       148     406.0

# %%
df.tail(7)
# Out:
#     Unnamed: 0  Duration         Date  Pulse  Maxpulse  Calories
# 25          25        60  2020/12/25'    102       126    334.50
# 26          26        60   12/26/2020    100       120    250.00
# 27          27        60  2020/12/27'     92       118    241.00
# 28          28        60  2020/12/28'    103       132    304.68
# 29          29        60  2020/12/29'    100       132    280.00
# 30          30        60  2020/12/30'    102       129    380.30
# 31          31        60  2020/12/31'     92       115    243.00

# %%
#lets see the shape of set
#total rows and column
df.shape
# Out:
# (32, 6)

# %%
# examine the data types
data_types = df.dtypes
data_types
# Out:
# Unnamed: 0      int64
# Duration        int64
# Date           object
# Pulse           int64
# Maxpulse        int64
# Calories      float64
# dtype: object

# %%
# identify null values variables
isnull = df.isnull()
isnull
# Out:
#     Unnamed: 0  Duration   Date  Pulse  Maxpulse  Calories
# 0        False     False  False  False     False     False
# 1        False     False  False  False     False     False
# 2        False     False  False  False     False     False
# 3        False     False  False  False     False     False
# 4        False     False  False  False     False     False
# 5        False     False  False  False     False     False
# 6        False     False  False  False     False     False
# 7        False     False  False  False     False     False
# 8        False     False  False  False     False     False
# 9        False     False  False  False     False     False
# 10       False     False  False  False     False     False
# 11       False     False  False  False     False     False
# 12       False     False  False  False     False     False
# 13       False     False  False  False     False     False
# 14       False     False  False  False     False     False
# ...

# %%
isnull_count = isnull.sum()
print("total number of null vslues:", isnull_count)
# Out:
# total number of null vslues: Unnamed: 0    0
# Duration      0
# Date          1
# Pulse         0
# Maxpulse      0
# Calories      0
# dtype: int64

# %%
#total nulls in dataset
total_isnull_count = isnull.sum().sum()
print("total nulls:", total_isnull_count)
# Out:
# total nulls: 1

# %%
# replace single quote with blank space and make date fromatted
df["Date"] = df["Date"].replace("'","", regex = True )

# %%
df
# Out:
#     Unnamed: 0  Duration        Date  Pulse  Maxpulse  Calories
# 0            0        60  2020/12/01    110       130    409.10
# 1            1        60  2020/12/02    117       145    479.00
# 2            2        60  2020/12/03    103       135    340.00
# 3            3        45  2020/12/04    109       175    282.40
# 4            4        45  2020/12/05    117       148    406.00
# 5            5        60  2020/12/06    102       127    300.00
# 6            6        60  2020/12/07    110       136    374.00
# 7            7       450  2020/12/08    104       134    253.30
# 8            8        30  2020/12/09    109       133    195.10
# 9            9        60  2020/12/10     98       124    269.00
# 10          10        60  2020/12/11    103       147    329.30
# 11          11        60  2020/12/12    100       120    250.70
# 12          12        60  2020/12/12    100       120    250.70
# 13          13        60  2020/12/13    106       128    345.30
# ...

# %%
# handle null values, return dataframe with no empty data cells
# we can use df.dropna(), it removes empty cells but will not change the dataframe
# if we want data frame to be changed, simply use inplace=True
new_df = df.dropna()
new_df
# Out:
#     Unnamed: 0  Duration        Date  Pulse  Maxpulse  Calories
# 0            0        60  2020/12/01    110       130    409.10
# 1            1        60  2020/12/02    117       145    479.00
# 2            2        60  2020/12/03    103       135    340.00
# 3            3        45  2020/12/04    109       175    282.40
# 4            4        45  2020/12/05    117       148    406.00
# 5            5        60  2020/12/06    102       127    300.00
# 6            6        60  2020/12/07    110       136    374.00
# 7            7       450  2020/12/08    104       134    253.30
# 8            8        30  2020/12/09    109       133    195.10
# 9            9        60  2020/12/10     98       124    269.00
# 10          10        60  2020/12/11    103       147    329.30
# 11          11        60  2020/12/12    100       120    250.70
# 12          12        60  2020/12/12    100       120    250.70
# 13          13        60  2020/12/13    106       128    345.30
# ...

# %%
isnull_count_newdf = new_df.isnull().sum()
print(isnull_count_newdf)
# Out:
# Unnamed: 0    0
# Duration      0
# Date          0
# Pulse         0
# Maxpulse      0
# Calories      0
# dtype: int64

# %%
# anpther way of handling the null values is by replacing the null values
df.fillna(130, inplace=True)
df
# Out:
#     Unnamed: 0  Duration        Date  Pulse  Maxpulse  Calories
# 0            0        60  2020/12/01    110       130    409.10
# 1            1        60  2020/12/02    117       145    479.00
# 2            2        60  2020/12/03    103       135    340.00
# 3            3        45  2020/12/04    109       175    282.40
# 4            4        45  2020/12/05    117       148    406.00
# 5            5        60  2020/12/06    102       127    300.00
# 6            6        60  2020/12/07    110       136    374.00
# 7            7       450  2020/12/08    104       134    253.30
# 8            8        30  2020/12/09    109       133    195.10
# 9            9        60  2020/12/10     98       124    269.00
# 10          10        60  2020/12/11    103       147    329.30
# 11          11        60  2020/12/12    100       120    250.70
# 12          12        60  2020/12/12    100       120    250.70
# 13          13        60  2020/12/13    106       128    345.30
# ...

# %%
df= pd.read_csv("/content/drive/MyDrive/ML practice/pandas_dataset.csv")
df["Calories"].fillna(130, inplace=True)
df
# Out:
# <ipython-input-30-7c7220c49ad2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(130, inplace=True)
#     Unnamed: 0  Duration         Date  Pulse  Maxpulse  Calories
# 0            0        60  2020/12/01'    110       130    409.10
# 1            1        60  2020/12/02'    117       145    479.00
# 2            2        60  2020/12/03'    103       135    340.00
# 3            3        45  2020/12/04'    109       175    282.40
# ...

# %%
# fill specific with mean, median, and mode
df = pd.read_csv("/content/drive/MyDrive/ML practice/pandas_dataset.csv")
x = df["Calories"].mean()
df["Calories"].fillna(x, inplace=True)
df
# Out:
# <ipython-input-31-ca3f2dd9be50>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(x, inplace=True)
#     Unnamed: 0  Duration         Date  Pulse  Maxpulse  Calories
# 0            0        60  2020/12/01'    110       130    409.10
# 1            1        60  2020/12/02'    117       145    479.00
# 2            2        60  2020/12/03'    103       135    340.00
# 3            3        45  2020/12/04'    109       175    282.40
# ...

# %%
df.to_csv("/content/drive/MyDrive/ML practice/pandasko_dataset.csv")

# %%
df = pd.read_csv(r"/content/Video_Games_Sales_as_at_22_Dec_2016.csv.zip")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ## Projects Practice
# - import nlibararies
# - data load
# - data structure
# - first and last few rows of dataset
# - examine datatypes
# - Null values
#  - Identify null values
#  - count null values by columns
#  -  total null values in dataset
# - ['Name', 'Year_of_Release', 'Genre', 'Publisher', 'Critic_Score',
#   'Critic_Count', 'User_Score', 'User_Count', 'Developer','Rating'] fill null vslues with a value 'Unknown'
# - Year_of_Release convert it to int

# %%
df = pd.read_csv(r"/content/Video_Games_Sales_as_at_22_Dec_2016.csv.zip")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %%
df.shape
# Out:
# (16719, 16)

# %%
data_types = df.dtypes
data_types
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
isnull =df.isnull()
isnull
# Out:
#         Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False     False            False  False      False     False     False
# 1      False     False            False  False      False     False     False
# 2      False     False            False  False      False     False     False
# 3      False     False            False  False      False     False     False
# 4      False     False            False  False      False     False     False
# ...      ...       ...              ...    ...        ...       ...       ...
# 16714  False     False            False  False      False     False     False
# 16715  False     False            False  False      False     False     False
# 16716  False     False            False  False      False     False     False
# 16717  False     False            False  False      False     False     False
# 16718  False     False            False  False      False     False     False
#
# ...

# %%
isnull_count = isnull.sum()
print("total number of null values:", isnull_count)
# Out:
# total number of null values: Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
data_types = df.dtypes
data_types
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
import numpy as np
df= df[['Name', 'Year_of_Release', 'Genre', 'Publisher', 'Critic_Score', 'Critic_Count',
       'User_Score', 'User_Count', 'Developer','Rating']].replace(np.nan,"Unknown")
df
# Out:
#                                 Name Year_of_Release         Genre  \
# 0                         Wii Sports          2006.0        Sports
# 1                  Super Mario Bros.          1985.0      Platform
# 2                     Mario Kart Wii          2008.0        Racing
# 3                  Wii Sports Resort          2009.0        Sports
# 4           Pokemon Red/Pokemon Blue          1996.0  Role-Playing
# ...                              ...             ...           ...
# 16714  Samurai Warriors: Sanada Maru          2016.0        Action
# 16715               LMA Manager 2007          2006.0        Sports
# 16716        Haitaka no Psychedelica          2016.0     Adventure
# 16717               Spirits & Spells          2003.0      Platform
# 16718            Winning Post 8 2016          2016.0    Simulation
#
#           Publisher Critic_Score Critic_Count User_Score User_Count Developer  \
# 0          Nintendo         76.0         51.0          8      322.0  Nintendo
# ...

# %%
## changing data type by replacing the unknown value into 0 and then only it is changed into int
# df.dtypes
# df["Year_of_Release"].dtype
# df ["Year_of_Release"] =df["Year_of_Release"].astype(int)
df["Year_of_Release"] = df["Year_of_Release"].replace("Unknown", "0").astype(int)
df["Year_of_Release"]
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16714    2016
# 16715    2006
# 16716    2016
# 16717    2003
# 16718    2016
# Name: Year_of_Release, Length: 16719, dtype: int64

# %%
#changing year_of_release datatype into int using fillna
df["Year_of_Release"].fillna("0", inplace=True)
df["Year_of_Release"] = df["Year_of_Release"].astype(int)
df["Year_of_Release"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 16714    0
# 16715    0
# 16716    0
# 16717    0
# 16718    0
# Name: Year_of_Release, Length: 16719, dtype: int64

# %% [markdown]
# # Day 3 Ml practice

# %% [markdown]
# ## Pandas_Indexing

# %%
import pandas as pd

# %%
# real world population
# indexing
df1 =pd.read_csv("/content/world_population.csv", index_col="Country")
df1
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df1.reset_index(inplace=True)
df1
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df1.set_index('Country', inplace= True)
df1
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df1.loc['Albania']
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
# index bata herna milxa dataset ko
df1.iloc[1]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df1.reset_index(inplace= True)
df1
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df1.set_index(['Continent', 'Country'], inplace =True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-4f35a9737a69> in <cell line: 0>()
# ----> 1 df1.set_index(['Continent', 'Country'], inplace =True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Continent', 'Country'] are in the columns"

# %%
df1
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul       41128771.0
# Europe    Albania             138  ALB            Tirana        2842321.0
# Africa    Algeria              34  DZA           Algiers       44903225.0
# Oceania   American Samoa      213  ASM         Pago Pago          44273.0
# Europe    Andorra             203  AND  Andorra la Vella          79824.0
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu          11572.0
# Africa    Western Sahara      172  ESH          El Aaiún         575986.0
# Asia      Yemen                46  YEM             Sanaa       33696614.0
# Africa    Zambia               63  ZMB            Lusaka       20017675.0
#           Zimbabwe             74  ZWE            Harare       16320537.0
#
# ...

# %%
df1.sort_index()
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %% [markdown]
# ## Group by and Aggregating

# %%
import pandas as pd
df2 = pd.read_csv("/content/Flavors.csv")
df2
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame = df2.groupby('Base Flavor')

# %%
group_by_frame.mean(numeric_only=True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
group_by_frame.count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
group_by_frame.sum()
# Out:
#                                                         Flavor  \
# Base Flavor
# Chocolate            ChocolateRocky RoadChocolte Fudge Brownie
# Vanilla      Mint Chocolate ChipVanillaCookie DoughPistachi...
#
#                        Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate          YesYesYes           25.2            21.7          47.1
# Vanilla      YesNoYesNoYesNo           34.2            33.9          68.1

# %%
df2.groupby(['Base Flavor', 'Liked']).agg({'Flavor Rating': ['mean', 'max', 'count', 'sum']})
# Out:
#                   Flavor Rating
#                            mean   max count   sum
# Base Flavor Liked
# Chocolate   Yes             8.4   8.8     3  25.2
# Vanilla     No              3.6   4.7     3  10.8
#             Yes             7.8  10.0     3  23.4

# %%
group_by_flavor = df2.groupby(['Base Flavor', 'Liked']).agg({'Flavor Rating': ['mean', 'max', 'count', 'sum']})

# %%
group_by_flavor.describe()
# Out:
#       Flavor Rating
#                mean        max count        sum
# count      3.000000   3.000000   3.0   3.000000
# mean       6.600000   7.833333   3.0  19.800000
# std        2.615339   2.779089   0.0   7.846018
# min        3.600000   4.700000   3.0  10.800000
# 25%        5.700000   6.750000   3.0  17.100000
# 50%        7.800000   8.800000   3.0  23.400000
# 75%        8.100000   9.400000   3.0  24.300000
# max        8.400000  10.000000   3.0  25.200000

# %% [markdown]
# ## Data merge, concatinate and Join

# %%
import pandas as pd
df1 = pd.read_csv("/content/LOTR.csv")
df1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
df2 = pd.read_csv("/content/LOTR 2.csv")
df2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
inner_join = df1.merge(df2, how='inner', on=['FellowshipID', 'FirstName'])
inner_join
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
outer_join = df1.merge(df2, how='outer')
outer_join
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
left_join = df1.merge(df2, how="left", on=['FellowshipID', 'FirstName'])
left_join
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
right_join = df1.merge(df2, how="right", on=['FellowshipID', 'FirstName'])
right_join
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %%
df = [df1, df2]
pd.concat(df)
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0
